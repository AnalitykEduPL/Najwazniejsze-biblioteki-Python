# %%
import numpy as np

# %% [markdown]
# ## Tworzenie tablicy

# %% [markdown]
# ##### jedno - wymiarowej

# %%
a = np.array([1,3,5,7])
a
# Out:
# array([1, 3, 5, 7])

# %%
b = np.arange(4)
b
# Out:
# array([0, 1, 2, 3])

# %%
np.arange(2,10,1)
# Out:
# array([2, 3, 4, 5, 6, 7, 8, 9])

# %%
np.linspace(0,10,6)
# Out:
# array([ 0.,  2.,  4.,  6.,  8., 10.])

# %% [markdown]
# ##### wielo - wymiarowej

# %%
c = np.array([[1,2,3],[4,5,6]])
c
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
# Out:
# -------------------------------------------------------------------
# AttributeError                    Traceback (most recent call last)
# <ipython-input-259-59afe4259651> in <module>()
# ----> 1 np.arrange(3,4)
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
d = np.zeros((2,3))
d
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
d = np.ones((2,3))
d
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.random.random((2,3))
# Out:
# array([[0.16868203, 0.31090109, 0.7210469 ],
#        [0.0750029 , 0.08401428, 0.96992496]])

# %% [markdown]
# ## Podstawowe operacje na tablicy

# %%
a+b
# Out:
# array([ 1,  4,  7, 10])

# %%
c+d
# Out:
# array([[2., 3., 4.],
#        [5., 6., 7.]])

# %%
c**2
# Out:
# array([[ 1,  4,  9],
#        [16, 25, 36]])

# %%
c.shape
# Out:
# (2, 3)

# %%
c.reshape(3,2)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
c.T
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
c > 3
# Out:
# array([[False, False, False],
#        [ True,  True,  True]])

# %% [markdown]
# ## Przeglądanie

# %%
a[2:]
# Out:
# array([5, 7])

# %%
c[:1]
# Out:
# array([[1, 2, 3]])

# %%
c[:1,1:]
# Out:
# array([[2, 3]])

# %%
for x in c:
    print (i)
    for y in x:
        print(y)
# Out:
# [4 5 6]
# 1
# 2
# 3
# [4 5 6]
# 4
# 5
# 6

# %%
for x in c.flat:
    print(x)
    
[x for x in c if x[1] < 3]
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# [array([1, 2, 3])]

# %% [markdown]
# ## Przetwarzanie obrazu

# %%
from skimage import io

# %%
pic = np.array(io.imread('http://analityk.edu.pl/wp-content/uploads/2020/01/fire.jpeg'))

# %%
import matplotlib.pyplot as plt
plt.imshow(pic)
plt.show()

# %%
plt.imshow(pic[::-1])
plt.show()

# %%
plt.imshow(pic[:,::-1])
plt.show()

# %%
plt.imshow(pic[300:450,150:600])
plt.show()

# %%
plt.imshow(pic+100)
plt.show()

# %%
pic = np.array(io.imread('fire.jpeg'))

mask = pic[:,:,0] < 200
pic[mask] = 255
plt.imshow(pic)
plt.show()

# %%
# Out:
# /home/ksec/projects/AnalitykEduPl/passgenerator

# %% [markdown]
# ## Funkcje wbudowane

# %%
x = np.random.random((3,5))
x
# Out:
# array([[0.43391468, 0.73430824, 0.92759808, 0.23966575, 0.16112573],
#        [0.85501039, 0.67383523, 0.45245038, 0.26001489, 0.86884395],
#        [0.17991555, 0.96628615, 0.22680872, 0.92979024, 0.52796391]])

# %%
print(x.sum())
print(x.min())
print(x.max())
print(x.mean())
# Out:
# 1126787
# 0
# 253
# 195.62274305555556
