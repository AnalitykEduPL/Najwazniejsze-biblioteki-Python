# %% [markdown]
# # Python Pandas - wszystko co musisz wiedzieć, aby zacząć
# ## Notebook, do artykułu na stronie [Analityk.edu.pl](http://analityk.edu.pl/python-pandas/)

# %% [markdown]
# Na początku, naszej przygody, musimy zaimportować bibliotekę Pandas.
# Standardowo, jest ona importowana jako pd

# %%
import pandas as pd

# %% [markdown]
# ## Pandas Series

# %% [markdown]
# Pandas Series, jest jednym z dwóch podstawowych typów danych w Pandas. Jest to typ, który reprezentuje jedną kolumnę.
# Spójrzmy na kilka operacji

# %%
a = pd.Series([-1,1,3,5,7])

# %%
a * 10
# Out:
# 0   -10
# 1    10
# 2    30
# 3    50
# 4    70
# dtype: int64

# %%
a.abs()
# Out:
# 0    1
# 1    1
# 2    3
# 3    5
# 4    7
# dtype: int64

# %%
a.describe()
# Out:
# count    5.000000
# mean     3.000000
# std      3.162278
# min     -1.000000
# 25%      1.000000
# 50%      3.000000
# 75%      5.000000
# max      7.000000
# dtype: float64

# %% [markdown]
# Domyślnym indexem, są liczby, zaczynające sie od 0.
# Możemy to zmienić

# %%
a.index = ['Pierwsza','Druga','Trzecia','Czwarta','Piąta']
a
# Out:
# Pierwsza   -1
# Druga       1
# Trzecia     3
# Czwarta     5
# Piąta       7
# dtype: int64

# %%
a['Piąta']
# Out:
# 7

# %% [markdown]
# ## Pandas DataFrame

# %% [markdown]
# Drugim, po Pandas Series, podsawowym typem danych w Pandas, to DataFrame.
# Jest to typ wielo-kolumnowy, który możemy porównać do efektywniejszej tabeli w Excelu.
# To właśnie na nim będziemy wykonywać większość operacji w Pandas.

# %% [markdown]
# ### Tworzenie DataFrame

# %% [markdown]
# #### Na bazie listy
#
# DataFrame, można tworzyć na wiele sposobów.
# Pierwszy to, na bazie listy.

# %%
a = [['Ania',24],['Michał',9],['Darek',40],['Ewa',43]]
df_a = pd.DataFrame(a)
df_a.columns = 'Imię', 'Wiek'
df_a
# Out:
#      Imię  Wiek
# 0    Ania    24
# 1  Michał     9
# 2   Darek    40
# 3     Ewa    43

# %% [markdown]
# #### Na bazie słownika
#
# Możemy też, utworzyć DataFrame, na bazie słownika:

# %%
b = {'Imię':['Ewa','Michał','Krzysiek','Kasia','Lucja'],'Miasto':['Warszawa','Kraków','Gdańsk','Poznań','Łódź']}
df_b = pd.DataFrame(b)
df_b
# Out:
#        Imię    Miasto
# 0       Ewa  Warszawa
# 1    Michał    Kraków
# 2  Krzysiek    Gdańsk
# 3     Kasia    Poznań
# 4     Lucja      Łódź

# %% [markdown]
# ### wczytywanie pliku
#
# Bardzo często, będzie tworzyć nasz DataFrame na bazie pliku. Możemy bez problemu, wczytać pliki typu CSV, XLS, JSON i więcej
#
# Zwyczajowo, zmienna typu DataFrame, nazywana jest 'df'

# %%
df = pd.read_csv('http://analityk.edu.pl/wp-content/uploads/2020/01/Countries.csv')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Przeglądanie DataFrame
#
# DataFrame, można przeglądać na wiele sposobów. Są one ważną podstawą, przed kolejnymi operacjami.

# %% [markdown]
# Jeżeli chcemy wyświetlić 3 pierwsze wiersze:

# %%
df[:3]
# Out:
#         Country                               Region  Population  \
# 0  Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1      Albania   EASTERN EUROPE                          3581655
# 2      Algeria   NORTHERN AFRICA                        32930091
#
#    Area sq. mi. Pop. Density sq. mi. Coastline coast/area ratio Net migration  \
# 0        647500                 48,0                       0,00         23,06
# 1         28748                124,6                       1,26         -4,93
# 2       2381740                 13,8                       0,04         -0,39
#
#   Infant mortality per 1000 births     GDP Literacy Phones per 1000 Climate  \
# 0                           163,07   700.0     36,0             3,2       1
# 1                            21,52  4500.0     86,5            71,2       3
# 2                               31  6000.0     70,0            78,1       1
#
#   Agriculture Industry Service
# 0        0,38     0,24    0,38
# 1       0,232    0,188   0,579
# 2       0,101      0,6   0,298

# %% [markdown]
# Jeżeli chcemy wyświetlić konkretne kolumny, specyfikujemy ich nazwę w [], oddzielone po przecinku

# %%
df[['Country','Region']]
# Out:
#                    Country                               Region
# 0             Afghanistan         ASIA (EX. NEAR EAST)
# 1                 Albania   EASTERN EUROPE
# 2                 Algeria   NORTHERN AFRICA
# 3          American Samoa   OCEANIA
# 4                 Andorra   WESTERN EUROPE
# 5                  Angola   SUB-SAHARAN AFRICA
# 6                Anguilla               LATIN AMER. & CARIB
# 7       Antigua & Barbuda               LATIN AMER. & CARIB
# 8               Argentina               LATIN AMER. & CARIB
# 9                 Armenia                  C.W. OF IND. STATES
# 10                  Aruba               LATIN AMER. & CARIB
# 11              Australia   OCEANIA
# 12                Austria   WESTERN EUROPE
# 13             Azerbaijan                  C.W. OF IND. STATES
# 14           Bahamas, The               LATIN AMER. & CARIB
# 15                Bahrain   NEAR EAST
# 16             Bangladesh         ASIA (EX. NEAR EAST)
# 17               Barbados               LATIN AMER. & CARIB
# 18                Belarus                  C.W. OF IND. STATES
# 19                Belgium   WESTERN EUROPE
# 20                 Belize               LATIN AMER. & CARIB
# 21                  Benin   SUB-SAHARAN AFRICA
# 22                Bermuda   NORTHERN AMERICA
# 23                 Bhutan         ASIA (EX. NEAR EAST)
# 24                Bolivia               LATIN AMER. & CARIB
# 25   Bosnia & Herzegovina   EASTERN EUROPE
# 26               Botswana   SUB-SAHARAN AFRICA
# 27                 Brazil               LATIN AMER. & CARIB
# 28     British Virgin Is.               LATIN AMER. & CARIB
# 29                 Brunei         ASIA (EX. NEAR EAST)
# ..                     ...                                  ...
# 197                 Syria   NEAR EAST
# 198                Taiwan         ASIA (EX. NEAR EAST)
# 199            Tajikistan                  C.W. OF IND. STATES
# 200              Tanzania   SUB-SAHARAN AFRICA
# 201              Thailand         ASIA (EX. NEAR EAST)
# 202                  Togo   SUB-SAHARAN AFRICA
# 203                 Tonga   OCEANIA
# 204     Trinidad & Tobago               LATIN AMER. & CARIB
# 205               Tunisia   NORTHERN AFRICA
# 206                Turkey   NEAR EAST
# 207          Turkmenistan                  C.W. OF IND. STATES
# 208     Turks & Caicos Is               LATIN AMER. & CARIB
# 209                Tuvalu   OCEANIA
# 210                Uganda   SUB-SAHARAN AFRICA
# 211               Ukraine                  C.W. OF IND. STATES
# 212  United Arab Emirates   NEAR EAST
# 213        United Kingdom   WESTERN EUROPE
# 214         United States   NORTHERN AMERICA
# 215               Uruguay               LATIN AMER. & CARIB
# 216            Uzbekistan                  C.W. OF IND. STATES
# 217               Vanuatu   OCEANIA
# 218             Venezuela               LATIN AMER. & CARIB
# 219               Vietnam         ASIA (EX. NEAR EAST)
# 220        Virgin Islands               LATIN AMER. & CARIB
# 221     Wallis and Futuna   OCEANIA
# 222             West Bank   NEAR EAST
# 223        Western Sahara   NORTHERN AFRICA
# 224                 Yemen   NEAR EAST
# 225                Zambia   SUB-SAHARAN AFRICA
# 226              Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %% [markdown]
# Aby wyświetlić, 3 pierwsze wiersze i 3 pierwsze kolumny, przy użyciu liczb w przypadku wierszy i kolumn, używamy funkcji 'iloc'

# %%
df.iloc[0:3,0:3]
# Out:
#         Country                               Region  Population
# 0  Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1      Albania   EASTERN EUROPE                          3581655
# 2      Algeria   NORTHERN AFRICA                        32930091

# %% [markdown]
# Jeżeli chcemy, wyświetlić wartości DataFrame, przy użyciu libcz, w przypadku wierszy oraz nazw, w przypadku kolumn, musimu użyć funkcji 'loc'

# %%
df.loc[:3,['Country','Region','Population']]
# Out:
#            Country                               Region  Population
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794

# %% [markdown]
# ## Podstawowe operacje

# %% [markdown]
# Na początku utwórzmy kopię zmiennej 'df', za pomocą funkcji copy(). Wybieramy tylko te kolumny, które nas interesują.

# %%
df_pop = df[['Country', 'Region', 'Population', 'Phones per 1000']].copy()
df_pop
# Out:
#                    Country                               Region  Population  \
# 0             Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1                 Albania   EASTERN EUROPE                          3581655
# 2                 Algeria   NORTHERN AFRICA                        32930091
# 3          American Samoa   OCEANIA                                   57794
# 4                 Andorra   WESTERN EUROPE                            71201
# 5                  Angola   SUB-SAHARAN AFRICA                     12127071
# 6                Anguilla               LATIN AMER. & CARIB           13477
# 7       Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8               Argentina               LATIN AMER. & CARIB        39921833
# 9                 Armenia                  C.W. OF IND. STATES      2976372
# 10                  Aruba               LATIN AMER. & CARIB           71891
# 11              Australia   OCEANIA                                20264082
# 12                Austria   WESTERN EUROPE                          8192880
# 13             Azerbaijan                  C.W. OF IND. STATES      7961619
# 14           Bahamas, The               LATIN AMER. & CARIB          303770
# 15                Bahrain   NEAR EAST                                698585
# 16             Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 17               Barbados               LATIN AMER. & CARIB          279912
# 18                Belarus                  C.W. OF IND. STATES     10293011
# 19                Belgium   WESTERN EUROPE                         10379067
# 20                 Belize               LATIN AMER. & CARIB          287730
# 21                  Benin   SUB-SAHARAN AFRICA                      7862944
# 22                Bermuda   NORTHERN AMERICA                          65773
# 23                 Bhutan         ASIA (EX. NEAR EAST)              2279723
# 24                Bolivia               LATIN AMER. & CARIB         8989046
# 25   Bosnia & Herzegovina   EASTERN EUROPE                          4498976
# 26               Botswana   SUB-SAHARAN AFRICA                      1639833
# 27                 Brazil               LATIN AMER. & CARIB       188078227
# 28     British Virgin Is.               LATIN AMER. & CARIB           23098
# 29                 Brunei         ASIA (EX. NEAR EAST)               379444
# ..                     ...                                  ...         ...
# 197                 Syria   NEAR EAST                              18881361
# 198                Taiwan         ASIA (EX. NEAR EAST)             23036087
# 199            Tajikistan                  C.W. OF IND. STATES      7320815
# 200              Tanzania   SUB-SAHARAN AFRICA                     37445392
# 201              Thailand         ASIA (EX. NEAR EAST)             64631595
# 202                  Togo   SUB-SAHARAN AFRICA                      5548702
# 203                 Tonga   OCEANIA                                  114689
# 204     Trinidad & Tobago               LATIN AMER. & CARIB         1065842
# 205               Tunisia   NORTHERN AFRICA                        10175014
# 206                Turkey   NEAR EAST                              70413958
# 207          Turkmenistan                  C.W. OF IND. STATES      5042920
# 208     Turks & Caicos Is               LATIN AMER. & CARIB           21152
# 209                Tuvalu   OCEANIA                                   11810
# 210                Uganda   SUB-SAHARAN AFRICA                     28195754
# 211               Ukraine                  C.W. OF IND. STATES     46710816
# 212  United Arab Emirates   NEAR EAST                               2602713
# 213        United Kingdom   WESTERN EUROPE                         60609153
# 214         United States   NORTHERN AMERICA                      298444215
# 215               Uruguay               LATIN AMER. & CARIB         3431932
# 216            Uzbekistan                  C.W. OF IND. STATES     27307134
# 217               Vanuatu   OCEANIA                                  208869
# 218             Venezuela               LATIN AMER. & CARIB        25730435
# 219               Vietnam         ASIA (EX. NEAR EAST)             84402966
# 220        Virgin Islands               LATIN AMER. & CARIB          108605
# 221     Wallis and Futuna   OCEANIA                                   16025
# 222             West Bank   NEAR EAST                               2460492
# 223        Western Sahara   NORTHERN AFRICA                          273008
# 224                 Yemen   NEAR EAST                              21456188
# 225                Zambia   SUB-SAHARAN AFRICA                     11502010
# 226              Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#     Phones per 1000
# 0               3,2
# 1              71,2
# 2              78,1
# 3             259,5
# 4             497,2
# 5               7,8
# 6             460,0
# 7             549,9
# 8             220,4
# 9             195,7
# 10            516,1
# 11            565,5
# 12            452,2
# 13            137,1
# 14            460,6
# 15            281,3
# 16              7,3
# 17            481,9
# 18            319,1
# 19            462,6
# 20            115,7
# 21              9,7
# 22            851,4
# 23             14,3
# 24             71,9
# 25            215,4
# 26             80,5
# 27            225,3
# 28            506,5
# 29            237,2
# ..              ...
# 197           153,8
# 198           591,0
# 199            33,5
# 200             4,0
# 201           108,9
# 202            10,6
# 203            97,7
# 204           303,5
# 205           123,6
# 206           269,5
# 207            74,6
# 208           269,5
# 209            59,3
# 210             3,6
# 211           259,9
# 212           475,3
# 213           543,5
# 214           898,0
# 215           291,4
# 216            62,9
# 217            32,6
# 218           140,1
# 219           187,7
# 220           652,8
# 221           118,6
# 222           145,2
# 223             NaN
# 224            37,2
# 225             8,2
# 226            26,8
#
# [227 rows x 4 columns]

# %% [markdown]
# W prosty sposób możemy wykonać operacje na całej kolumnie. Jak np. zawienić populację, aby była przedstawiona w milionach. Czyli dzielimy przez 1 000 000.

# %%
df_pop['Population'] /= 1000000

# %% [markdown]
# Czy też utworzyć nową kolumną

# %%
df_pop['Nowa kolumna'] = 1

# %% [markdown]
# Popularną i pomocją funcją, jest funkcja 'head()', wyświetlająca 5 pierwszych wierszy.

# %%
df_pop.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)            31.056997
# 1         Albania   EASTERN EUROPE                         3.581655
# 2         Algeria   NORTHERN AFRICA                       32.930091
# 3  American Samoa   OCEANIA                                0.057794
# 4         Andorra   WESTERN EUROPE                         0.071201
#
#   Phones per 1000 Liczba telefonów  Nowa kolumna
# 0             3,2              3,2             1
# 1            71,2             71,2             1
# 2            78,1             78,1             1
# 3           259,5            259,5             1
# 4           497,2            497,2             1

# %% [markdown]
# ## Iteracje for loop
#
# Bez problemu, możemy przetwarzać, DataFrame, za pomocą pętli for.
# Możemy to efektywnie wykonać za pomocą 2 metod:

# %% [markdown]
# ##### Metoda 1 - funkcja iterrows
#
# Zwraca ona index oraz zawartość aktualnego wiersza.
# W poniższym przykładnie, dodatkowo tworzymy, nową kolumnę, oraz nadajemy jej wartość za pomoca funkcji loc, która umożliwia nam poruszanie się za pomocą numeru wiersza, oraz nazwy kolumny.

# %%
for index, row in df_pop.iterrows():
    if row['Population'] > 100:
        df_pop.loc[index,'Size'] = 'Big'
        print (row['Country'], df_pop.loc[index,'Size'])
# Out:
# Bangladesh  Big
# Brazil  Big
# China  Big
# India  Big
# Indonesia  Big
# Japan  Big
# Mexico  Big
# Nigeria  Big
# Pakistan  Big
# Russia  Big
# United States  Big

# %% [markdown]
# ##### Metoda 2 - funkcja itertuples
#
# zwraca nam ona krotkę, tak więc index, musimy z niej 'wyczytać'.
# Jest to metoda, która daje, taki sam efekt, jak powyższa, jednak jest wydajniejsza

# %%
for row in df_pop.itertuples():
    if row.Population > 200:
        print(row.Index, row.Country, row.Population)
# Out:
# 42 China  1313.973713
# 94 India  1095.351995
# 95 Indonesia  245.452739
# 214 United States  298.444215

# %% [markdown]
# ## Filtrowanie DataFrame

# %% [markdown]
# ### za pomoca maski
#
# Podobnie, jak w przypadku NumPy, możemy utworzyć maskę logiczną, którą następnie nakładamy na DataFrame. Zobaczmy:

# %% [markdown]
# Przykład maski, która posiada wartość True w przypadku populacji o konkretnej wartości:

# %%
df_pop.Population == 147.365352
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16      True
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 197    False
# 198    False
# 199    False
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# 205    False
# 206    False
# 207    False
# 208    False
# 209    False
# 210    False
# 211    False
# 212    False
# 213    False
# 214    False
# 215    False
# 216    False
# 217    False
# 218    False
# 219    False
# 220    False
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# 226    False
# Name: Population, Length: 227, dtype: bool

# %% [markdown]
# Nakładamy maskę na nasz DataFrame. Identyczny rezultat osiągniemy za pomocą pętli for, jednak maski są czytelniejsze i wydajniejsze. Poniższe 2 linijki są równoznaczne.

# %%
df_pop[df_pop.Population == 147.365352]
df_pop[df_pop['Population'] == 147.365352]
# Out:
#         Country                         Region  Population Phones per 1000  \
# 16  Bangladesh   ASIA (EX. NEAR EAST)           147.365352             7,3
#
#    Size
# 16  Big

# %% [markdown]
# Możemy również łączyć wartunki. Tutaj jednak, musimy zadbać, aby obydwa, były ujęte w nawiasy ()

# %%
df_pop[(df_pop['Population']>100) & (df_pop['Population']<200)]
# Out:
#          Country                               Region  Population  \
# 16   Bangladesh         ASIA (EX. NEAR EAST)           147.365352
# 27       Brazil               LATIN AMER. & CARIB      188.078227
# 103       Japan         ASIA (EX. NEAR EAST)           127.463611
# 135      Mexico               LATIN AMER. & CARIB      107.449525
# 152     Nigeria   SUB-SAHARAN AFRICA                   131.859731
# 156    Pakistan         ASIA (EX. NEAR EAST)           165.803560
# 169      Russia                  C.W. OF IND. STATES   142.893540
#
#     Phones per 1000 Size
# 16              7,3  Big
# 27            225,3  Big
# 103           461,2  Big
# 135           181,6  Big
# 152             9,3  Big
# 156            31,8  Big
# 169           280,6  Big

# %% [markdown]
# ## Sumowanie, Grupowanie, oraz inne kalkulacje
#
# Każdy, kto jest zaznajomiony z SQL, jest również przyzwyczajony do grupowania danych, oraz wyliczania dla danej grupy sum, max, min itd. Zobaczmy jak możemy to samo osiągnąć z Pandas.

# %% [markdown]
# Na początku, policzmy statystyki, całej kolumny - 'Population'

# %%
print( df_pop['Population'].sum() )
print( df_pop['Population'].max() )
print( df_pop['Population'].min() )
print( df_pop['Population'].mean() )
# Out:
# 6524.044551
# 1313.973713
# 0.007026
# 28.740284365638768

# %% [markdown]
# Następnie, dokonajmy grupowania, po kolumnie - 'Region', oraz policzmy te same statystyki, dla każdego z regionów, z osobna

# %%
print( df_pop.groupby('Region')['Population'].size() )
print( df_pop.groupby('Region')['Population'].sum() )
print( df_pop.groupby('Region')['Population'].mean() )
# Out:
# Region
# ASIA (EX. NEAR EAST)                   28
# BALTICS                                 3
# C.W. OF IND. STATES                    12
# EASTERN EUROPE                         12
# LATIN AMER. & CARIB                    45
# NEAR EAST                              16
# NORTHERN AFRICA                         6
# NORTHERN AMERICA                        5
# OCEANIA                                21
# SUB-SAHARAN AFRICA                     51
# WESTERN EUROPE                         28
# Name: Population, dtype: int64
# Region
# ASIA (EX. NEAR EAST)                   3687.982236
# BALTICS                                   7.184974
# C.W. OF IND. STATES                     280.081548
# EASTERN EUROPE                          119.914717
# LATIN AMER. & CARIB                     561.824599
# NEAR EAST                               195.068377
# NORTHERN AFRICA                         161.407133
# NORTHERN AMERICA                        331.672307
# OCEANIA                                  33.131662
# SUB-SAHARAN AFRICA                      749.437000
# WESTERN EUROPE                          396.339998
# Name: Population, dtype: float64
# Region
# ASIA (EX. NEAR EAST)                   131.713651
# BALTICS                                  2.394991
# C.W. OF IND. STATES                     23.340129
# EASTERN EUROPE                           9.992893
# LATIN AMER. & CARIB                     12.484991
# NEAR EAST                               12.191774
# NORTHERN AFRICA                         26.901189
# NORTHERN AMERICA                        66.334461
# OCEANIA                                  1.577698
# SUB-SAHARAN AFRICA                      14.694843
# WESTERN EUROPE                          14.155000
# Name: Population, dtype: float64

# %% [markdown]
# W powyższym przykładzie, uzyskaliśmy rządane wartości w osobnym DataFrame. Możemy policzyć interesujące nas wartości, i przypisać do kolumn w jednym DataFrame, za pomocą funkcji 'agg'

# %%
df_pop.groupby('Region')['Population'].agg([min, max, sum])
# Out:
#                                           min          max          sum
# Region
# ASIA (EX. NEAR EAST)                 0.359008  1313.973713  3687.982236
# BALTICS                              1.324333     3.585906     7.184974
# C.W. OF IND. STATES                  2.976372   142.893540   280.081548
# EASTERN EUROPE                       2.010347    38.536869   119.914717
# LATIN AMER. & CARIB                  0.009439   188.078227   561.824599
# NEAR EAST                            0.698585    70.413958   195.068377
# NORTHERN AFRICA                      0.273008    78.887007   161.407133
# NORTHERN AMERICA                     0.007026   298.444215   331.672307
# OCEANIA                              0.011810    20.264082    33.131662
# SUB-SAHARAN AFRICA                   0.007502   131.859731   749.437000
# WESTERN EUROPE                       0.027928    82.422299   396.339998

# %% [markdown]
# Jeżeli chcemy chcemy zapisać wyniki w kolumnach o konkretnych nazwach, możemy przekazać do funkcji agg, słownik:

# %%
df_pop.groupby('Region', as_index=False)['Population'].agg({"Suma":"sum", "Max":"max"})
# Out:
#                                  Region          Max         Suma
# 0         ASIA (EX. NEAR EAST)           1313.973713  3687.982236
# 1   BALTICS                                 3.585906     7.184974
# 2                  C.W. OF IND. STATES    142.893540   280.081548
# 3   EASTERN EUROPE                         38.536869   119.914717
# 4               LATIN AMER. & CARIB       188.078227   561.824599
# 5   NEAR EAST                              70.413958   195.068377
# 6   NORTHERN AFRICA                        78.887007   161.407133
# 7   NORTHERN AMERICA                      298.444215   331.672307
# 8   OCEANIA                                20.264082    33.131662
# 9   SUB-SAHARAN AFRICA                    131.859731   749.437000
# 10  WESTERN EUROPE                         82.422299   396.339998

# %% [markdown]
# ## Łączenie DataFrame - SQL Join
#
# Bardzo szybko, dojdziemy do momentu, w którym mamy dwa, zbiory danych, które chcemy połączyć, za pomocą wspólnego klucza. W tym przypadku, mamy do dyspozycji funkcje 'merge'. Zdefiniujmy 2 DataFrame, po czym połączmy je na 4 sposoby:

# %%
a = [['Ania',24],['Michał',9],['Darek',40],['Ewa',43]]
df_a = pd.DataFrame(a)
df_a.columns = 'Imię', 'Wiek'
df_a
# Out:
#      Imię  Wiek
# 0    Ania    24
# 1  Michał     9
# 2   Darek    40
# 3     Ewa    43

# %%
b = {'Imię':['Ewa','Michał','Krzysiek','Kasia','Lucja'],'Miasto':['Warszawa','Kraków','Gdańsk','Poznań','Łódź']}
df_b = pd.DataFrame(b)
df_b
# Out:
#        Imię    Miasto
# 0       Ewa  Warszawa
# 1    Michał    Kraków
# 2  Krzysiek    Gdańsk
# 3     Kasia    Poznań
# 4     Lucja      Łódź

# %% [markdown]
# 1 - Uzyskanie części wspólnej:

# %%
pd.merge(df_a, df_b, on='Imię')
# Out:
#      Imię  Wiek    Miasto
# 0  Michał     9    Kraków
# 1     Ewa    43  Warszawa

# %% [markdown]
# 2 - Wszystkie wiersze ze zbioru lewego, pasujące wiersze ze zbioru prawego

# %%
pd.merge(df_a, df_b, on='Imię', how='left')
# Out:
#      Imię  Wiek    Miasto
# 0    Ania    24       NaN
# 1  Michał     9    Kraków
# 2   Darek    40       NaN
# 3     Ewa    43  Warszawa

# %% [markdown]
# 3 - Wszystkie wiersze ze zbioru prawego, pasujące wiersze ze zbioru lewego

# %%
pd.merge(df_a, df_b, on='Imię', how='right')
# Out:
#        Imię  Wiek    Miasto
# 0    Michał   9.0    Kraków
# 1       Ewa  43.0  Warszawa
# 2  Krzysiek   NaN    Gdańsk
# 3     Kasia   NaN    Poznań
# 4     Lucja   NaN      Łódź

# %% [markdown]
# 4 - Wszystkie wiersze

# %%
pd.merge(df_a, df_b, on='Imię', how='outer')
# Out:
#        Imię  Wiek    Miasto
# 0      Ania  24.0       NaN
# 1    Michał   9.0    Kraków
# 2     Darek  40.0       NaN
# 3       Ewa  43.0  Warszawa
# 4  Krzysiek   NaN    Gdańsk
# 5     Kasia   NaN    Poznań
# 6     Lucja   NaN      Łódź

# %% [markdown]
# ## Wykresy
#
# Ostatnią rzeczą, o której wspomnimy to fakt, że Pandas współpracuje z biblioteką Matplotlib i umożliwia szybkie przygotowanie podstawowych wykresów. Prosty przykład, załączamy poniżej, jednak temat zostanie omówiony w osobnym artykule.

# %%
import matplotlib.pyplot as plt
df_pop.groupby('Region')['Population'].sum().plot(kind='pie')
plt.show()
